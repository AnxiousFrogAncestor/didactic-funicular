# %%
import marimo as mo

# %%
from pyspark.sql import SparkSession

spark = (SparkSession.builder
    .appName("DataLoader")
    .master("local[*]") # use all local cores
    .getOrCreate())

df = spark.read.parquet("datasets/bing_covid-19_data.parquet")

# %%
policy_df = spark.read.parquet("datasets/covid_policy_tracker.parquet")

# %%
policy_df.show(vertical = True)
# Out:
# -RECORD 0-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-01
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 1-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-02
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 2-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-03
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 3-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-04
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 4-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-05
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 5-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-06
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 6-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-07
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 7-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-08
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 8-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-09
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 9-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-10
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 10----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-11
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 11----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-12
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 12----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-13
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 13----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-14
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 14----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-15
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 15----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-16
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 16----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-17
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 17----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-18
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 18----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-19
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 19----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-20
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# only showing top 20 rows

# %% [markdown]
# # Exploring the datatypes and data

# %%
df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- updated: date (nullable = true)
#  |-- confirmed: integer (nullable = true)
#  |-- confirmed_change: integer (nullable = true)
#  |-- deaths: integer (nullable = true)
#  |-- deaths_change: short (nullable = true)
#  |-- recovered: integer (nullable = true)
#  |-- recovered_change: integer (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- iso2: string (nullable = true)
#  |-- iso3: string (nullable = true)
#  |-- country_region: string (nullable = true)
#  |-- admin_region_1: string (nullable = true)
#  |-- iso_subdivision: string (nullable = true)
#  |-- admin_region_2: string (nullable = true)
#  |-- load_time: timestamp (nullable = true)

# %%
df.show(n=20)
# Out:
# +------+----------+---------+----------------+------+-------------+---------+----------------+--------+---------+----+----+--------------+--------------+---------------+--------------+--------------------+
# |    id|   updated|confirmed|confirmed_change|deaths|deaths_change|recovered|recovered_change|latitude|longitude|iso2|iso3|country_region|admin_region_1|iso_subdivision|admin_region_2|           load_time|
# +------+----------+---------+----------------+------+-------------+---------+----------------+--------+---------+----+----+--------------+--------------+---------------+--------------+--------------------+
# |338995|2020-01-21|      262|            NULL|     0|         NULL|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |338996|2020-01-22|      313|              51|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |338997|2020-01-23|      578|             265|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |338998|2020-01-24|      841|             263|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |338999|2020-01-25|     1320|             479|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339000|2020-01-26|     2014|             694|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339001|2020-01-27|     2798|             784|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339002|2020-01-28|     4593|            1795|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339003|2020-01-29|     6065|            1472|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339004|2020-01-30|     7818|            1753|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339005|2020-01-31|     9826|            2008|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339006|2020-02-01|    11953|            2127|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339007|2020-02-02|    14557|            2604|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339008|2020-02-03|    17386|            2829|   362|          362|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339009|2020-02-04|    20625|            3239|   426|           64|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339010|2020-02-05|    24549|            3924|   492|           66|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339011|2020-02-06|    28256|            3707|   565|           73|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339012|2020-02-07|    31420|            3164|   638|           73|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339013|2020-02-08|    34822|            3402|   724|           86|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# |339014|2020-02-09|    37494|            2672|   813|           89|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|2025-05-10 02:05:...|
# +------+----------+---------+----------------+------+-------------+---------+----------------+--------+---------+----+----+--------------+--------------+---------------+--------------+--------------------+
# only showing top 20 rows

# %%
reduced_df = df.drop("load_time")

# %%
reduced_df.show(20)
# Out:
# +------+----------+---------+----------------+------+-------------+---------+----------------+--------+---------+----+----+--------------+--------------+---------------+--------------+
# |    id|   updated|confirmed|confirmed_change|deaths|deaths_change|recovered|recovered_change|latitude|longitude|iso2|iso3|country_region|admin_region_1|iso_subdivision|admin_region_2|
# +------+----------+---------+----------------+------+-------------+---------+----------------+--------+---------+----+----+--------------+--------------+---------------+--------------+
# |338995|2020-01-21|      262|            NULL|     0|         NULL|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |338996|2020-01-22|      313|              51|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |338997|2020-01-23|      578|             265|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |338998|2020-01-24|      841|             263|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |338999|2020-01-25|     1320|             479|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339000|2020-01-26|     2014|             694|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339001|2020-01-27|     2798|             784|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339002|2020-01-28|     4593|            1795|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339003|2020-01-29|     6065|            1472|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339004|2020-01-30|     7818|            1753|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339005|2020-01-31|     9826|            2008|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339006|2020-02-01|    11953|            2127|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339007|2020-02-02|    14557|            2604|     0|            0|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339008|2020-02-03|    17386|            2829|   362|          362|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339009|2020-02-04|    20625|            3239|   426|           64|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339010|2020-02-05|    24549|            3924|   492|           66|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339011|2020-02-06|    28256|            3707|   565|           73|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339012|2020-02-07|    31420|            3164|   638|           73|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339013|2020-02-08|    34822|            3402|   724|           86|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# |339014|2020-02-09|    37494|            2672|   813|           89|     NULL|            NULL|    NULL|     NULL|NULL|NULL|     Worldwide|          NULL|           NULL|          NULL|
# +------+----------+---------+----------------+------+-------------+---------+----------------+--------+---------+----+----+--------------+--------------+---------------+--------------+
# only showing top 20 rows

# %%
reduced_df.describe().show(vertical=True)
# Out:
# -RECORD 0--------------------------------
#  summary          | count
#  id               | 4766736
#  confirmed        | 4766736
#  confirmed_change | 4761213
#  deaths           | 4668438
#  deaths_change    | 4657186
#  recovered        | 1114073
#  recovered_change | 1104531
#  latitude         | 4765761
#  longitude        | 4765761
#  iso2             | 4759261
#  iso3             | 4759261
#  country_region   | 4766736
#  admin_region_1   | 4530381
#  iso_subdivision  | 3932598
#  admin_region_2   | 3779699
# -RECORD 1--------------------------------
#  summary          | mean
#  id               | 1.4054495640649387E8
#  confirmed        | 169962.092957529
#  confirmed_change | 358.2463617989785
#  deaths           | 2426.586312595348
#  deaths_change    | 4.01827562824418
#  recovered        | 104600.44465308826
#  recovered_change | 300.800233764376
#  latitude         | 35.22958179161724
#  longitude        | -52.356955835003234
#  iso2             | NULL
#  iso3             | NULL
#  country_region   | NULL
#  admin_region_1   | NULL
#  iso_subdivision  | NULL
#  admin_region_2   | NULL
# -RECORD 2--------------------------------
#  summary          | stddev
#  id               | 6.238529919518856E7
#  confirmed        | 4963724.86797934
#  confirmed_change | 22102.718063156943
#  deaths           | 63445.037682405564
#  deaths_change    | 128.8268054212618
#  recovered        | 1319509.6794360054
#  recovered_change | 28677.891313144915
#  latitude         | 14.911955575137739
#  longitude        | 67.631644414577
#  iso2             | NULL
#  iso3             | NULL
#  country_region   | NULL
#  admin_region_1   | NULL
#  iso_subdivision  | NULL
#  admin_region_2   | NULL
# -RECORD 3--------------------------------
#  summary          | min
#  id               | 19
#  confirmed        | 0
#  confirmed_change | -22069144
#  deaths           | -1
#  deaths_change    | -31669
#  recovered        | 0
#  recovered_change | -24776512
#  latitude         | -80.20264
#  longitude        | -176.2045
#  iso2             | AD
#  iso3             | ABW
#  country_region   | Afghanistan
#  admin_region_1   | Aargau
#  iso_subdivision  | AR-A
#  admin_region_2   | Aachen
# -RECORD 4--------------------------------
#  summary          | max
#  id               | 229707573
#  confirmed        | 675622359
#  confirmed_change | 12009862
#  deaths           | 7507739
#  deaths_change    | 28865
#  recovered        | 95897262
#  recovered_change | 12820706
#  latitude         | 78.6954
#  longitude        | 178.6661
#  iso2             | ZW
#  iso3             | ZWE
#  country_region   | Zimbabwe
#  admin_region_1   | Świętokrzyskie
#  iso_subdivision  | US-WY
#  admin_region_2   | Zwickau

# %% [markdown]
# ## Get the number of unique strings per column

# %%
from pyspark.sql.types import StringType
from pyspark.sql.functions import countDistinct, col

def count_distinct_strings(df):
    """
    Counts the number of distinct values for each string-type column in a DataFrame, 
    excluding nulls.

    Parameters
    ----------
    df : pyspark.sql.DataFrame
        The input DataFrame containing various columns, including string-type columns.

    Returns
    -------
    pyspark.sql.DataFrame
        A DataFrame with one row where each column corresponds to the number of distinct 
        non-null values in the original string-type column, with each column renamed to 
        indicate the distinct count (e.g., 'column_name_distinct').
    """
    # get the string type columns from the schema
    string_cols = [field.name for field in df.schema.fields if isinstance(field.dataType, StringType)]

    # filter out nulls
    # must filter seperately, filter only accepts a single condition
    filtered_df = df
    for c in string_cols:
        filtered_df = filtered_df.filter(col(c).isNotNull())

    # count the distinct strings, and rename the columns once in the iteration
    result = filtered_df.agg(
        *[countDistinct(col(c)).alias(f"{c}_distinct") for c in string_cols]
    )

    return result

distinct_counts = count_distinct_strings(df)
distinct_counts.show()
# Out:
# +-------------+-------------+-----------------------+-----------------------+------------------------+-----------------------+
# |iso2_distinct|iso3_distinct|country_region_distinct|admin_region_1_distinct|iso_subdivision_distinct|admin_region_2_distinct|
# +-------------+-------------+-----------------------+-----------------------+------------------------+-----------------------+
# |           11|           11|                     11|                    108|                     108|                   2807|
# +-------------+-------------+-----------------------+-----------------------+------------------------+-----------------------+

# %%
reduced_df.select("country_region").distinct().orderBy("country_region").show() #use select to return a dataframe
# Out:
# +-------------------+
# |     country_region|
# +-------------------+
# |        Afghanistan|
# |            Albania|
# |            Algeria|
# |     American Samoa|
# |            Andorra|
# |             Angola|
# |           Anguilla|
# |         Antarctica|
# |Antigua and Barbuda|
# |          Argentina|
# |            Armenia|
# |              Aruba|
# |          Australia|
# |            Austria|
# |         Azerbaijan|
# |            Bahamas|
# |            Bahrain|
# |         Bangladesh|
# |           Barbados|
# |            Belarus|
# +-------------------+
# only showing top 20 rows

# %%
covid_stats = ["id", "updated", "confirmed", "confirmed_change", "deaths", "deaths_change", "recovered", "recovered_change", "country_region"]

# %% [markdown]
# # Get the Hungarian covid statistics

# %%
reduced_df.select(covid_stats).where(condition=col("country_region")=="Hungary").show(5)
# Out:
# +-------+----------+---------+----------------+------+-------------+---------+----------------+--------------+
# |     id|   updated|confirmed|confirmed_change|deaths|deaths_change|recovered|recovered_change|country_region|
# +-------+----------+---------+----------------+------+-------------+---------+----------------+--------------+
# |7169162|2020-03-04|        2|            NULL|     0|         NULL|     NULL|            NULL|       Hungary|
# |7169165|2020-03-05|        3|               1|     0|            0|     NULL|            NULL|       Hungary|
# |7169167|2020-03-06|        4|               1|     0|            0|        0|            NULL|       Hungary|
# |7169169|2020-03-07|        7|               3|     0|            0|        0|               0|       Hungary|
# |7169183|2020-03-08|        9|               2|     0|            0|        0|               0|       Hungary|
# +-------+----------+---------+----------------+------+-------------+---------+----------------+--------------+
# only showing top 5 rows

# %%
reduced_df.select(covid_stats).where((col("country_region") == "Hungary") & (reduced_df.confirmed > 50)).show(5) #wrap each logic condition seperately
# Out:
# +-------+----------+---------+----------------+------+-------------+---------+----------------+--------------+
# |     id|   updated|confirmed|confirmed_change|deaths|deaths_change|recovered|recovered_change|country_region|
# +-------+----------+---------+----------------+------+-------------+---------+----------------+--------------+
# |7169200|2020-03-18|       58|               8|     1|            0|        2|               0|       Hungary|
# |7169202|2020-03-19|       73|              15|     1|            0|        2|               0|       Hungary|
# |7169204|2020-03-20|       85|              12|     4|            3|        7|               5|       Hungary|
# |7169206|2020-03-21|      103|              18|     4|            0|        7|               0|       Hungary|
# |7169208|2020-03-22|      131|              28|     6|            2|       16|               9|       Hungary|
# +-------+----------+---------+----------------+------+-------------+---------+----------------+--------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import count, min, max

max_cases = reduced_df.select(covid_stats).filter((col("country_region") == "Hungary")).agg(*[max(col) for col in covid_stats if col not in ["id", "updated", "country_region"]]).collect()[0]

# %%
max_cases
# Out:
# Row(max(confirmed)=2195926, max(confirmed_change)=20597, max(deaths)=48751, max(deaths_change)=834, max(recovered)=784539, max(recovered_change)=24851)

# %%
max_cases
# Out:
# Row(max(confirmed)=2195926, max(confirmed_change)=20597, max(deaths)=48751, max(deaths_change)=834, max(recovered)=784539, max(recovered_change)=24851)

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number, rank, dense_rank, lag, lead, sum, avg

# %%
type(max_cases)
# Out:
# pyspark.sql.types.Row

# %%
from pyspark.sql import Row
import datetime
import pandas as pd

hungarian_covid_stats_df = reduced_df.select(covid_stats).filter((col("country_region") == "Hungary"))

max_dict = {}
for column, i in zip(hungarian_covid_stats_df.columns, range(len(max_cases))):
    date_for_max_case = hungarian_covid_stats_df.select("updated").where(max_cases[i]==hungarian_covid_stats_df[2+i])
    if hungarian_covid_stats_df.columns[2+i] in ["confirmed_change", "deaths_change", "recovered_change"]:
        max_dict[hungarian_covid_stats_df.columns[2+i]] = date_for_max_case.collect()[0]["updated"]

pandas_df = pd.DataFrame([max_dict])
print(max_dict)
print(pandas_df)
# Out:
# {'confirmed_change': datetime.date(2021, 3, 31), 'deaths_change': datetime.date(2021, 4, 1), 'recovered_change': datetime.date(2021, 5, 13)}
#   confirmed_change deaths_change recovered_change
# 0       2021-03-31    2021-04-01       2021-05-13

# %%
from pyspark.sql.functions import when

hungarian_covid_stats_extra = (
    hungarian_covid_stats_df
    .withColumn(
        "percentage_of_recovered", 
        when(col("confirmed") == 0, 0)
        .otherwise(col("recovered") / col("confirmed"))
    )
    .withColumn(
        "percentage_of_deaths", 
        when(col("confirmed") == 0, 0)  
        .otherwise(col("deaths") / col("confirmed"))
    )
    .withColumn(
        "active_cases", 
        when(col("confirmed") == 0, 0)
        .otherwise(col("confirmed") - col("recovered") - col("deaths"))
    )
)

date_window = Window.partitionBy("updated").orderBy("updated").rowsBetween(-7, 0) #assuming dates are unique
hungarian_covid_stats_extra = (hungarian_covid_stats_extra.withColumn("avg_last_7_active",avg("active_cases").over(date_window)))

date_window_lagging = Window.orderBy("updated") #no need for rows_between, or partition by, we apply globally
hungarian_covid_stats_extra = hungarian_covid_stats_extra.withColumn("pastweek_weekly_avg_active", lag("avg_last_7_active").over(date_window_lagging)) #could possibly change offset for lag

hungarian_covid_stats_extra = hungarian_covid_stats_extra.withColumn(
    "danger_zone",
    when(col("active_cases") > col("avg_last_7_active"), "danger")
    .when((col("active_cases") <= col("avg_last_7_active")) & (col("avg_last_7_active")*0.5 < col("active_cases")), "mild_danger")
    .otherwise("normal")
)

hungarian_covid_stats_extra = hungarian_covid_stats_extra.withColumn("weekly_active_cases_change", col("avg_last_7_active")-col("pastweek_weekly_avg_active"))

hungarian_covid_stats_extra.show(30, vertical=True)
# Out:
# -RECORD 0------------------------------------------
#  id                         | 7169162
#  updated                    | 2020-03-04
#  confirmed                  | 2
#  confirmed_change           | NULL
#  deaths                     | 0
#  deaths_change              | NULL
#  recovered                  | NULL
#  recovered_change           | NULL
#  country_region             | Hungary
#  percentage_of_recovered    | NULL
#  percentage_of_deaths       | 0.0
#  active_cases               | NULL
#  avg_last_7_active          | NULL
#  pastweek_weekly_avg_active | NULL
#  danger_zone                | normal
#  weekly_active_cases_change | NULL
# -RECORD 1------------------------------------------
#  id                         | 7169165
#  updated                    | 2020-03-05
#  confirmed                  | 3
#  confirmed_change           | 1
#  deaths                     | 0
#  deaths_change              | 0
#  recovered                  | NULL
#  recovered_change           | NULL
#  country_region             | Hungary
#  percentage_of_recovered    | NULL
#  percentage_of_deaths       | 0.0
#  active_cases               | NULL
#  avg_last_7_active          | NULL
#  pastweek_weekly_avg_active | NULL
#  danger_zone                | normal
#  weekly_active_cases_change | NULL
# -RECORD 2------------------------------------------
#  id                         | 7169167
#  updated                    | 2020-03-06
#  confirmed                  | 4
#  confirmed_change           | 1
#  deaths                     | 0
#  deaths_change              | 0
#  recovered                  | 0
#  recovered_change           | NULL
#  country_region             | Hungary
#  percentage_of_recovered    | 0.0
#  percentage_of_deaths       | 0.0
#  active_cases               | 4
#  avg_last_7_active          | 4.0
#  pastweek_weekly_avg_active | NULL
#  danger_zone                | mild_danger
#  weekly_active_cases_change | NULL
# -RECORD 3------------------------------------------
#  id                         | 7169169
#  updated                    | 2020-03-07
#  confirmed                  | 7
#  confirmed_change           | 3
#  deaths                     | 0
#  deaths_change              | 0
#  recovered                  | 0
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.0
#  percentage_of_deaths       | 0.0
#  active_cases               | 7
#  avg_last_7_active          | 7.0
#  pastweek_weekly_avg_active | 4.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 3.0
# -RECORD 4------------------------------------------
#  id                         | 7169183
#  updated                    | 2020-03-08
#  confirmed                  | 9
#  confirmed_change           | 2
#  deaths                     | 0
#  deaths_change              | 0
#  recovered                  | 0
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.0
#  percentage_of_deaths       | 0.0
#  active_cases               | 9
#  avg_last_7_active          | 9.0
#  pastweek_weekly_avg_active | 7.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 2.0
# -RECORD 5------------------------------------------
#  id                         | 7169184
#  updated                    | 2020-03-09
#  confirmed                  | 12
#  confirmed_change           | 3
#  deaths                     | 0
#  deaths_change              | 0
#  recovered                  | 0
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.0
#  percentage_of_deaths       | 0.0
#  active_cases               | 12
#  avg_last_7_active          | 12.0
#  pastweek_weekly_avg_active | 9.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 3.0
# -RECORD 6------------------------------------------
#  id                         | 7169186
#  updated                    | 2020-03-10
#  confirmed                  | 12
#  confirmed_change           | 0
#  deaths                     | 0
#  deaths_change              | 0
#  recovered                  | 0
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.0
#  percentage_of_deaths       | 0.0
#  active_cases               | 12
#  avg_last_7_active          | 12.0
#  pastweek_weekly_avg_active | 12.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 0.0
# -RECORD 7------------------------------------------
#  id                         | 7169188
#  updated                    | 2020-03-11
#  confirmed                  | 13
#  confirmed_change           | 1
#  deaths                     | 0
#  deaths_change              | 0
#  recovered                  | 0
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.0
#  percentage_of_deaths       | 0.0
#  active_cases               | 13
#  avg_last_7_active          | 13.0
#  pastweek_weekly_avg_active | 12.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 1.0
# -RECORD 8------------------------------------------
#  id                         | 7169189
#  updated                    | 2020-03-12
#  confirmed                  | 16
#  confirmed_change           | 3
#  deaths                     | 0
#  deaths_change              | 0
#  recovered                  | 0
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.0
#  percentage_of_deaths       | 0.0
#  active_cases               | 16
#  avg_last_7_active          | 16.0
#  pastweek_weekly_avg_active | 13.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 3.0
# -RECORD 9------------------------------------------
#  id                         | 7169191
#  updated                    | 2020-03-13
#  confirmed                  | 19
#  confirmed_change           | 3
#  deaths                     | 0
#  deaths_change              | 0
#  recovered                  | 0
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.0
#  percentage_of_deaths       | 0.0
#  active_cases               | 19
#  avg_last_7_active          | 19.0
#  pastweek_weekly_avg_active | 16.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 3.0
# -RECORD 10-----------------------------------------
#  id                         | 7169193
#  updated                    | 2020-03-14
#  confirmed                  | 30
#  confirmed_change           | 11
#  deaths                     | 0
#  deaths_change              | 0
#  recovered                  | 1
#  recovered_change           | 1
#  country_region             | Hungary
#  percentage_of_recovered    | 0.03333333333333333
#  percentage_of_deaths       | 0.0
#  active_cases               | 29
#  avg_last_7_active          | 29.0
#  pastweek_weekly_avg_active | 19.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 10.0
# -RECORD 11-----------------------------------------
#  id                         | 7169195
#  updated                    | 2020-03-15
#  confirmed                  | 32
#  confirmed_change           | 2
#  deaths                     | 1
#  deaths_change              | 1
#  recovered                  | 1
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.03125
#  percentage_of_deaths       | 0.03125
#  active_cases               | 30
#  avg_last_7_active          | 30.0
#  pastweek_weekly_avg_active | 29.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 1.0
# -RECORD 12-----------------------------------------
#  id                         | 7169197
#  updated                    | 2020-03-16
#  confirmed                  | 39
#  confirmed_change           | 7
#  deaths                     | 1
#  deaths_change              | 0
#  recovered                  | 1
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.02564102564102564
#  percentage_of_deaths       | 0.02564102564102564
#  active_cases               | 37
#  avg_last_7_active          | 37.0
#  pastweek_weekly_avg_active | 30.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 7.0
# -RECORD 13-----------------------------------------
#  id                         | 7169199
#  updated                    | 2020-03-17
#  confirmed                  | 50
#  confirmed_change           | 11
#  deaths                     | 1
#  deaths_change              | 0
#  recovered                  | 2
#  recovered_change           | 1
#  country_region             | Hungary
#  percentage_of_recovered    | 0.04
#  percentage_of_deaths       | 0.02
#  active_cases               | 47
#  avg_last_7_active          | 47.0
#  pastweek_weekly_avg_active | 37.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 10.0
# -RECORD 14-----------------------------------------
#  id                         | 7169200
#  updated                    | 2020-03-18
#  confirmed                  | 58
#  confirmed_change           | 8
#  deaths                     | 1
#  deaths_change              | 0
#  recovered                  | 2
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.034482758620689655
#  percentage_of_deaths       | 0.017241379310344827
#  active_cases               | 55
#  avg_last_7_active          | 55.0
#  pastweek_weekly_avg_active | 47.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 8.0
# -RECORD 15-----------------------------------------
#  id                         | 7169202
#  updated                    | 2020-03-19
#  confirmed                  | 73
#  confirmed_change           | 15
#  deaths                     | 1
#  deaths_change              | 0
#  recovered                  | 2
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.0273972602739726
#  percentage_of_deaths       | 0.0136986301369863
#  active_cases               | 70
#  avg_last_7_active          | 70.0
#  pastweek_weekly_avg_active | 55.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 15.0
# -RECORD 16-----------------------------------------
#  id                         | 7169204
#  updated                    | 2020-03-20
#  confirmed                  | 85
#  confirmed_change           | 12
#  deaths                     | 4
#  deaths_change              | 3
#  recovered                  | 7
#  recovered_change           | 5
#  country_region             | Hungary
#  percentage_of_recovered    | 0.08235294117647059
#  percentage_of_deaths       | 0.047058823529411764
#  active_cases               | 74
#  avg_last_7_active          | 74.0
#  pastweek_weekly_avg_active | 70.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 4.0
# -RECORD 17-----------------------------------------
#  id                         | 7169206
#  updated                    | 2020-03-21
#  confirmed                  | 103
#  confirmed_change           | 18
#  deaths                     | 4
#  deaths_change              | 0
#  recovered                  | 7
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.06796116504854369
#  percentage_of_deaths       | 0.038834951456310676
#  active_cases               | 92
#  avg_last_7_active          | 92.0
#  pastweek_weekly_avg_active | 74.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 18.0
# -RECORD 18-----------------------------------------
#  id                         | 7169208
#  updated                    | 2020-03-22
#  confirmed                  | 131
#  confirmed_change           | 28
#  deaths                     | 6
#  deaths_change              | 2
#  recovered                  | 16
#  recovered_change           | 9
#  country_region             | Hungary
#  percentage_of_recovered    | 0.12213740458015267
#  percentage_of_deaths       | 0.04580152671755725
#  active_cases               | 109
#  avg_last_7_active          | 109.0
#  pastweek_weekly_avg_active | 92.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 17.0
# -RECORD 19-----------------------------------------
#  id                         | 7169210
#  updated                    | 2020-03-23
#  confirmed                  | 167
#  confirmed_change           | 36
#  deaths                     | 8
#  deaths_change              | 2
#  recovered                  | 16
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.09580838323353294
#  percentage_of_deaths       | 0.04790419161676647
#  active_cases               | 143
#  avg_last_7_active          | 143.0
#  pastweek_weekly_avg_active | 109.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 34.0
# -RECORD 20-----------------------------------------
#  id                         | 7169212
#  updated                    | 2020-03-24
#  confirmed                  | 187
#  confirmed_change           | 20
#  deaths                     | 9
#  deaths_change              | 1
#  recovered                  | 21
#  recovered_change           | 5
#  country_region             | Hungary
#  percentage_of_recovered    | 0.11229946524064172
#  percentage_of_deaths       | 0.0481283422459893
#  active_cases               | 157
#  avg_last_7_active          | 157.0
#  pastweek_weekly_avg_active | 143.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 14.0
# -RECORD 21-----------------------------------------
#  id                         | 7169214
#  updated                    | 2020-03-25
#  confirmed                  | 226
#  confirmed_change           | 39
#  deaths                     | 10
#  deaths_change              | 1
#  recovered                  | 21
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.09292035398230089
#  percentage_of_deaths       | 0.04424778761061947
#  active_cases               | 195
#  avg_last_7_active          | 195.0
#  pastweek_weekly_avg_active | 157.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 38.0
# -RECORD 22-----------------------------------------
#  id                         | 7169216
#  updated                    | 2020-03-26
#  confirmed                  | 261
#  confirmed_change           | 35
#  deaths                     | 10
#  deaths_change              | 0
#  recovered                  | 28
#  recovered_change           | 7
#  country_region             | Hungary
#  percentage_of_recovered    | 0.10727969348659004
#  percentage_of_deaths       | 0.038314176245210725
#  active_cases               | 223
#  avg_last_7_active          | 223.0
#  pastweek_weekly_avg_active | 195.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 28.0
# -RECORD 23-----------------------------------------
#  id                         | 7169218
#  updated                    | 2020-03-27
#  confirmed                  | 300
#  confirmed_change           | 39
#  deaths                     | 10
#  deaths_change              | 0
#  recovered                  | 34
#  recovered_change           | 6
#  country_region             | Hungary
#  percentage_of_recovered    | 0.11333333333333333
#  percentage_of_deaths       | 0.03333333333333333
#  active_cases               | 256
#  avg_last_7_active          | 256.0
#  pastweek_weekly_avg_active | 223.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 33.0
# -RECORD 24-----------------------------------------
#  id                         | 7169219
#  updated                    | 2020-03-28
#  confirmed                  | 343
#  confirmed_change           | 43
#  deaths                     | 11
#  deaths_change              | 1
#  recovered                  | 34
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.09912536443148688
#  percentage_of_deaths       | 0.03206997084548105
#  active_cases               | 298
#  avg_last_7_active          | 298.0
#  pastweek_weekly_avg_active | 256.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 42.0
# -RECORD 25-----------------------------------------
#  id                         | 7169221
#  updated                    | 2020-03-29
#  confirmed                  | 408
#  confirmed_change           | 65
#  deaths                     | 13
#  deaths_change              | 2
#  recovered                  | 34
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.08333333333333333
#  percentage_of_deaths       | 0.031862745098039214
#  active_cases               | 361
#  avg_last_7_active          | 361.0
#  pastweek_weekly_avg_active | 298.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 63.0
# -RECORD 26-----------------------------------------
#  id                         | 7169223
#  updated                    | 2020-03-30
#  confirmed                  | 447
#  confirmed_change           | 39
#  deaths                     | 15
#  deaths_change              | 2
#  recovered                  | 34
#  recovered_change           | 0
#  country_region             | Hungary
#  percentage_of_recovered    | 0.07606263982102908
#  percentage_of_deaths       | 0.03355704697986577
#  active_cases               | 398
#  avg_last_7_active          | 398.0
#  pastweek_weekly_avg_active | 361.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 37.0
# -RECORD 27-----------------------------------------
#  id                         | 7169225
#  updated                    | 2020-03-31
#  confirmed                  | 492
#  confirmed_change           | 45
#  deaths                     | 16
#  deaths_change              | 1
#  recovered                  | 37
#  recovered_change           | 3
#  country_region             | Hungary
#  percentage_of_recovered    | 0.07520325203252033
#  percentage_of_deaths       | 0.032520325203252036
#  active_cases               | 439
#  avg_last_7_active          | 439.0
#  pastweek_weekly_avg_active | 398.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 41.0
# -RECORD 28-----------------------------------------
#  id                         | 7169227
#  updated                    | 2020-04-01
#  confirmed                  | 525
#  confirmed_change           | 33
#  deaths                     | 20
#  deaths_change              | 4
#  recovered                  | 40
#  recovered_change           | 3
#  country_region             | Hungary
#  percentage_of_recovered    | 0.0761904761904762
#  percentage_of_deaths       | 0.0380952380952381
#  active_cases               | 465
#  avg_last_7_active          | 465.0
#  pastweek_weekly_avg_active | 439.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 26.0
# -RECORD 29-----------------------------------------
#  id                         | 7169229
#  updated                    | 2020-04-02
#  confirmed                  | 585
#  confirmed_change           | 60
#  deaths                     | 21
#  deaths_change              | 1
#  recovered                  | 42
#  recovered_change           | 2
#  country_region             | Hungary
#  percentage_of_recovered    | 0.07179487179487179
#  percentage_of_deaths       | 0.035897435897435895
#  active_cases               | 522
#  avg_last_7_active          | 522.0
#  pastweek_weekly_avg_active | 465.0
#  danger_zone                | mild_danger
#  weekly_active_cases_change | 57.0
# only showing top 30 rows

# %% [markdown]
# # Save the dataframe

# %%
#hungarian_covid_stats_extra.write.mode("overwrite").parquet("hungarian_covid_stats.parquet")

# %% [markdown]
# # Compute the aggregate statistics of "countries" with "united substring"

# %%
#https://stackoverflow.com/questions/38610559/convert-spark-dataframe-column-to-python-list
united_countries = (reduced_df.filter(col("country_region").contains("United"))
                         .select("country_region")
                         .distinct()
                         .toPandas()['country_region'].tolist())

# %%
united_countries
# Out:
# ['United States', 'United Arab Emirates', 'United Kingdom']

# %%
united_df = reduced_df.select(covid_stats).where((col("country_region").isin(united_countries)) & (reduced_df.confirmed > 50)).groupby(col("country_region")).agg(sum(col="confirmed").alias("SumConfirmed")) #wrap each logic condition seperately

united_window = Window.orderBy(col("SumConfirmed").desc())  # no need to partition, we window globally

united_df = united_df.withColumn("dense_rank", dense_rank().over(united_window))

united_df.show()
# Out:
# +--------------------+------------+----------+
# |      country_region|SumConfirmed|dense_rank|
# +--------------------+------------+----------+
# |       United States|140905721002|         1|
# |      United Kingdom| 21159388426|         2|
# |United Arab Emirates|   645314878|         3|
# +--------------------+------------+----------+

# %%
reduced_df.join(policy_df, (reduced_df.country_region == policy_df.countryname) & (reduced_df.country_region == "Hungary"), how="inner").show(10, vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-26
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 1-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-25
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 2-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-24
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 3-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-23
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 4-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-22
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 5-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-21
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 6-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-20
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 7-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-19
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 8-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-18
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 9-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-17
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# only showing top 10 rows

# %%
reduced_df.createOrReplaceTempView("covid_view")
policy_df.createOrReplaceTempView("policy_view")

#spark.sql("SELECT * FROM policy_view").show()
policy_df.show(vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-01
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 1-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-02
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 2-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-03
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 3-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-04
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 4-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-05
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 5-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-06
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 6-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-07
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 7-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-08
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 8-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-09
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 9-----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-10
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 10----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-11
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 11----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-12
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 12----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-13
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 13----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-14
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 14----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-15
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 15----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-16
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 16----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-17
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 17----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-18
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 18----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-19
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 19----------------------------------------------------
#  countryname                           | Aruba
#  countrycode                           | ABW
#  date                                  | 2020-01-20
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | 0.0
#  e4_international_support              | 0.0
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 0.0
#  h3_contact_tracing                    | 0.0
#  h4_emergency_investment_in_healthcare | 0.0
#  h5_investment_in_vaccines             | 0.0
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | AW
#  load_date                             | 2022-07-27 02:05:...
# only showing top 20 rows

# %%
policy_df.printSchema()
# Out:
# root
#  |-- countryname: string (nullable = true)
#  |-- countrycode: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- c1_school_closing: double (nullable = true)
#  |-- c1_flag: boolean (nullable = true)
#  |-- c2_workplace_closing: double (nullable = true)
#  |-- c2_flag: boolean (nullable = true)
#  |-- c3_cancel_public_events: double (nullable = true)
#  |-- c3_flag: boolean (nullable = true)
#  |-- c4_restrictions_on_gatherings: double (nullable = true)
#  |-- c4_flag: boolean (nullable = true)
#  |-- c5_close_public_transport: double (nullable = true)
#  |-- c5_flag: boolean (nullable = true)
#  |-- c6_stay_at_home_requirements: double (nullable = true)
#  |-- c6_flag: boolean (nullable = true)
#  |-- c7_restrictions_on_internal_movement: double (nullable = true)
#  |-- c7_flag: boolean (nullable = true)
#  |-- c8_international_travel_controls: double (nullable = true)
#  |-- e1_income_support: double (nullable = true)
#  |-- e1_flag: boolean (nullable = true)
#  |-- e2_debt/contract_relief: double (nullable = true)
#  |-- e3_fiscal_measures: double (nullable = true)
#  |-- e4_international_support: double (nullable = true)
#  |-- h1_public_information_campaigns: double (nullable = true)
#  |-- h1_flag: boolean (nullable = true)
#  |-- h2_testing_policy: double (nullable = true)
#  |-- h3_contact_tracing: double (nullable = true)
#  |-- h4_emergency_investment_in_healthcare: double (nullable = true)
#  |-- h5_investment_in_vaccines: double (nullable = true)
#  |-- m1_wildcard: string (nullable = true)
#  |-- confirmedcases: short (nullable = true)
#  |-- confirmeddeaths: short (nullable = true)
#  |-- stringencyindex: double (nullable = true)
#  |-- stringencyindexfordisplay: double (nullable = true)
#  |-- legacystringencyindex: double (nullable = true)
#  |-- legacystringencyindexfordisplay: double (nullable = true)
#  |-- iso_country: string (nullable = true)
#  |-- load_date: timestamp (nullable = true)

# %%
from pyspark.sql.functions import expr

# %%
(policy_df.select("countryname",
                 expr("e1_income_support != 0").alias("income_support"))
    .filter(expr("e1_income_support != 0"))
    .show())
# Out:
# +-----------+--------------+
# |countryname|income_support|
# +-----------+--------------+
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# |      Aruba|          true|
# +-----------+--------------+
# only showing top 20 rows

# %%
spark.sql("SELECT * FROM covid_view INNER JOIN policy_view ON covid_view.country_region == policy_view.countryname WHERE covid_view.country_region=='Hungary'").show(vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-26
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 1-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-25
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 2-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-24
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 3-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-23
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 4-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-22
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 5-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-21
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 6-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-20
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 7-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-19
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 8-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-18
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 9-----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-17
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 10----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-16
#  c1_school_closing                     | NULL
#  c1_flag                               | NULL
#  c2_workplace_closing                  | NULL
#  c2_flag                               | NULL
#  c3_cancel_public_events               | NULL
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | NULL
#  c4_flag                               | NULL
#  c5_close_public_transport             | NULL
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | NULL
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | NULL
#  c7_flag                               | NULL
#  c8_international_travel_controls      | NULL
#  e1_income_support                     | NULL
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | NULL
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | NULL
#  h1_flag                               | NULL
#  h2_testing_policy                     | NULL
#  h3_contact_tracing                    | NULL
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | NULL
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 11----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-15
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 2.0
#  h3_contact_tracing                    | 1.0
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 12----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-14
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 2.0
#  h3_contact_tracing                    | 1.0
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 13----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-13
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 2.0
#  h3_contact_tracing                    | 1.0
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
# ...
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 2.0
#  h3_contact_tracing                    | 1.0
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 16----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-10
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 2.0
#  h3_contact_tracing                    | 1.0
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 17----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-09
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 2.0
#  h3_contact_tracing                    | 1.0
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 18----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-08
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 2.0
#  h3_contact_tracing                    | 1.0
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# -RECORD 19----------------------------------------------------
#  id                                    | 7169162
#  updated                               | 2020-03-04
#  confirmed                             | 2
#  confirmed_change                      | NULL
#  deaths                                | 0
#  deaths_change                         | NULL
#  recovered                             | NULL
#  recovered_change                      | NULL
#  latitude                              | 47.16519
#  longitude                             | 19.41204
#  iso2                                  | HU
#  iso3                                  | HUN
#  country_region                        | Hungary
#  admin_region_1                        | NULL
#  iso_subdivision                       | NULL
#  admin_region_2                        | NULL
#  countryname                           | Hungary
#  countrycode                           | HUN
#  date                                  | 2022-07-07
#  c1_school_closing                     | 0.0
#  c1_flag                               | NULL
#  c2_workplace_closing                  | 0.0
#  c2_flag                               | NULL
#  c3_cancel_public_events               | 0.0
#  c3_flag                               | NULL
#  c4_restrictions_on_gatherings         | 0.0
#  c4_flag                               | NULL
#  c5_close_public_transport             | 0.0
#  c5_flag                               | NULL
#  c6_stay_at_home_requirements          | 0.0
#  c6_flag                               | NULL
#  c7_restrictions_on_internal_movement  | 0.0
#  c7_flag                               | NULL
#  c8_international_travel_controls      | 0.0
#  e1_income_support                     | 0.0
#  e1_flag                               | NULL
#  e2_debt/contract_relief               | 0.0
#  e3_fiscal_measures                    | NULL
#  e4_international_support              | NULL
#  h1_public_information_campaigns       | 0.0
#  h1_flag                               | NULL
#  h2_testing_policy                     | 2.0
#  h3_contact_tracing                    | 1.0
#  h4_emergency_investment_in_healthcare | NULL
#  h5_investment_in_vaccines             | NULL
#  m1_wildcard                           | NULL
#  confirmedcases                        | NULL
#  confirmeddeaths                       | NULL
#  stringencyindex                       | 0.0
#  stringencyindexfordisplay             | 0.0
#  legacystringencyindex                 | NULL
#  legacystringencyindexfordisplay       | NULL
#  iso_country                           | HU
#  load_date                             | 2022-07-27 02:05:...
# only showing top 20 rows

# %%
spark.sql("SELECT country_region, MAX(confirmed) AS CUMULATIVE_CONFIRMED FROM covid_view GROUP BY country_region ORDER BY cumulative_confirmed DESC").show()
# Out:
# +--------------+--------------------+
# |country_region|CUMULATIVE_CONFIRMED|
# +--------------+--------------------+
# |     Worldwide|           675622359|
# |      Bulgaria|           183974853|
# | United States|           103582936|
# |         India|            44688722|
# |        France|            38591184|
# |       Germany|            38202571|
# |        Brazil|            37063464|
# |         Japan|            33260228|
# |   South Korea|            30555102|
# |         Italy|            25603510|
# |United Kingdom|            24396534|
# |        Russia|            22342128|
# |        Turkey|            17042722|
# |         Spain|            13763336|
# |       Vietnam|            11526950|
# |     Australia|            11385534|
# |        Taiwan|            10055439|
# |     Argentina|            10044125|
# |   Netherlands|             8607177|
# |          Iran|             7569483|
# +--------------+--------------------+
# only showing top 20 rows
